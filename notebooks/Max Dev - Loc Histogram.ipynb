# %%
# import modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load data into a dataframe
path = '../data/GP_Alumni_List_Cleaned.csv'
df = pd.read_csv(path).copy()
df
# Out:
#      Affiliation  PrefClassYear Degrees State         Country   Latitude  \
# 0         Alumni         1983.0     BSc    CO   United States  39.783730
# 1         Alumni         1995.0     BSc    CO   United States  39.783730
# 2         Alumni         2013.0     MSc   NaN         Bahrain  26.155125
# 3         Alumni         1999.0     MSc   NaN  United Kingdom  54.702354
# 4         Alumni         1982.0     BSc    OK   United States  39.783730
# ...          ...            ...     ...   ...             ...        ...
# 2225      Alumni         2012.0     BSc    CO   United States  39.783730
# 2226      Alumni         1982.0     BSc    TX   United States  39.783730
# 2227      Alumni         1981.0     BSc    UT   United States  39.783730
# 2228      Alumni         2019.0     BSc    CO   United States  39.783730
# 2229      Alumni         2012.0     MSc    CO   United States  39.783730
#
#        Longitude
# 0    -100.445882
# 1    -100.445882
# 2      50.534461
# 3      -3.276575
# 4    -100.445882
# ...          ...
# 2225 -100.445882
# 2226 -100.445882
# 2227 -100.445882
# 2228 -100.445882
# 2229 -100.445882
#
# [2230 rows x 7 columns]

# %%
# value count graph for states
value_counts = df['State'].value_counts()

plt.figure(figsize=(20, 6))
plt.bar(value_counts.index, value_counts.values)
# Out:
# <BarContainer object of 51 artists>

# %%
# value count graph for states
value_counts = df['Country'].value_counts()

plt.figure(figsize=(20, 6))
plt.bar(value_counts.index, value_counts.values)
plt.xticks(rotation=45, horizontalalignment='right')
plt.tight_layout()
